# %% [markdown]
# ![ex3.jpeg](attachment:ex3.jpeg)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#qn 1
x1=np.array([1,2,6,18])
y1=np.array([3,10,12,20])
plt.plot(x1,y1,'ro:',markerfacecolor='green',markeredgecolor='green',)
plt.show()

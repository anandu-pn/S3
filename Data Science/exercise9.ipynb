# %% [markdown]
# program to implement linear regression algoritham using any standard dataset availabele in public domain and find accuracy of the algoritham

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature - BMI (index 2)
diabetes_X = diabetes_X[:, np.newaxis, 2]

# %%
# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# Print model coefficients and performance
print("Coefficients: \n", regr.coef_)
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
print("Coefficient of determination (R^2 score): %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination (R^2 score): 0.47

# %%
# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")

# Sort the data for a smoother regression line
sorted_idx = np.argsort(diabetes_X_test[:, 0])
plt.plot(diabetes_X_test[sorted_idx], diabetes_y_pred[sorted_idx], color="blue", linewidth=3)

plt.xlabel("bmi")
plt.ylabel("diabetes progression")
plt.title("Linear Regression: BMI vs Diabetes Progression")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()
